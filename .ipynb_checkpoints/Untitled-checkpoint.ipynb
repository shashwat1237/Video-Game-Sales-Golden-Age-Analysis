# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import train test split
from sklearn.model_selection import train_test_split
#standardd scaler , one hot encoder
from sklearn.preprocessing import StandardScaler ,OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
#random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
df=pd.read_csv("vgsales.csv")

# %%
df=df.dropna(subset=["Year","Publisher","Rank"])
df["Year"]=df["Year"].astype(int)
sns.histplot(df["Year"])

# %%
df=df[df["Global_Sales"]>0]

# %%
sns.histplot(df["Global_Sales"])

# %%
plt.figure(figsize=(20,7))
sns.barplot(df.groupby("Year")["Global_Sales"].sum())

# %%
plt.figure(figsize=(20,7))
sns.barplot(df.groupby("Year")["Rank"].mean())

#plt.xticks(rotation=90)

# %%
mgs=df["Global_Sales"].mean()
sgs=df["Global_Sales"].std()
df["Global_Sales_z"]=(df["Global_Sales"]-mgs)/sgs

mr=df["Rank"].mean()
sr=df["Rank"].std()
df["Rank_z"]=(df["Rank"]-mr)/sr

# %%
plt.figure(figsize=(20,7))
a=df.groupby("Year")["Rank_z"].mean()
b=df.groupby("Year")["Global_Sales_z"].mean()
sns.lineplot(a,color="blue")
sns.lineplot(b,color="red")

# %%
a.corr(b)
